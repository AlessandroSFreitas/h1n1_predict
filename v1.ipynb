# %%
# import libs

import pandas as pd
import seaborn as sns
import matplotlib

# %%
# check libs versions

print(pd.__version__)
print(sns.__version__)
print(matplotlib.__version__)
# Out:
# 1.3.4
# 0.11.2
# 3.4.3

# %%
flu_2019_brazil = pd.read_csv("data/influd_19.csv", sep=";", low_memory=False)

# %%
flu_2019_brazil
# Out:
#        DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0      10/01/2019        2  06/01/2019        2        MG
# 1      03/01/2019        1  01/01/2019        1        SP
# 2      02/01/2019        1  31/12/2018        1        PE
# 3      10/01/2019        2  07/01/2019        2        SP
# 4      11/01/2019        2  06/01/2019        2        PE
# ...           ...      ...         ...      ...       ...
# 48523  12/12/2019       50  09/12/2019       50        BA
# 48524  05/11/2019       45  23/10/2019       43        PA
# 48525  11/04/2020       15  26/12/2019       52        SP
# 48526  31/10/2019       44  29/10/2019       44        BA
# 48527  08/04/2020       15  01/12/2019       49        ES
#
#                               ID_REGIONA  CO_REGIONA      ID_MUNICIP  \
# 0                         BELO HORIZONTE        1449  BELO HORIZONTE
# 1                          GVE I CAPITAL        1331       SAO PAULO
# ...

# %%
for i in flu_2019_brazil.columns:
    print(i)
# Out:
# DT_NOTIFIC
# SEM_NOT
# DT_SIN_PRI
# SEM_PRI
# SG_UF_NOT
# ID_REGIONA
# CO_REGIONA
# ID_MUNICIP
# CO_MUN_NOT
# ID_UNIDADE
# CO_UNI_NOT
# CS_SEXO
# DT_NASC
# NU_IDADE_N
# TP_IDADE
# COD_IDADE
# CS_GESTANT
# CS_RACA
# CS_ESCOL_N
# ID_PAIS
# CO_PAIS
# SG_UF
# CO_RG_RESI
# ID_MN_RESI
# CO_MUN_RES
# CS_ZONA
# SURTO_SG
# NOSOCOMIAL
# AVE_SUINO
# FEBRE
# TOSSE
# GARGANTA
# DISPNEIA
# DESC_RESP
# SATURACAO
# DIARREIA
# VOMITO
# OUTRO_SIN
# OUTRO_DES
# PUERPERA
# CARDIOPATI
# HEMATOLOGI
# SIND_DOWN
# HEPATICA
# ASMA
# DIABETES
# NEUROLOGIC
# PNEUMOPATI
# IMUNODEPRE
# RENAL
# OBESIDADE
# OBES_IMC
# OUT_MORBI
# MORB_DESC
# VACINA
# DT_UT_DOSE
# MAE_VAC
# DT_VAC_MAE
# M_AMAMENTA
# DT_DOSEUNI
# DT_1_DOSE
# DT_2_DOSE
# ANTIVIRAL
# TP_ANTIVIR
# OUT_ANTIV
# DT_ANTIVIR
# HOSPITAL
# DT_INTERNA
# SG_UF_INTE
# ID_RG_INTE
# CO_RG_INTE
# ID_MN_INTE
# CO_MU_INTE
# UTI
# DT_ENTUTI
# DT_SAIDUTI
# SUPORT_VEN
# RAIOX_RES
# RAIOX_OUT
# DT_RAIOX
# AMOSTRA
# DT_COLETA
# TP_AMOSTRA
# OUT_AMOST
# REQUI_GAL
# ...
